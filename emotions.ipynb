# %%
import os
import shutil
from zipfile import ZipFile

import keras
from keras import layers
from tensorflow import data as tf_data
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from tensorflow.keras.models import Sequential

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
if os.path.exists('fer2013.zip')==False:
    # !kaggle datasets download -d msambare/fer2013
else:
  print('File is already downloaded')
# Out:
# Dataset URL: https://www.kaggle.com/datasets/msambare/fer2013
# License(s): DbCL-1.0
# Downloading fer2013.zip to /content
#  99% 60.0M/60.3M [00:03<00:00, 21.9MB/s]
# 100% 60.3M/60.3M [00:03<00:00, 16.7MB/s]

# %%
with ZipFile('fer2013.zip', 'r') as zf:
    zf.extractall()

# %%
train_datagen = ImageDataGenerator(
    width_shift_range = 0.1,        # Randomly shift the width of images by up to 10%
    height_shift_range = 0.1,       # Randomly shift the height of images by up to 10%
    horizontal_flip = True,         # Flip images horizontally at random
    rescale = 1./255,               # Rescale pixel values to be between 0 and 1
    validation_split = 0.2          # Set aside 20% of the data for validation
)

validation_datagen = ImageDataGenerator(
    rescale = 1./255,               # Rescale pixel values to be between 0 and 1
    validation_split = 0.2          # Set aside 20% of the data for validation
)

# %%
train_generator = train_datagen.flow_from_directory(
    directory = 'train',           # Directory containing the training data
    target_size = (48, 48),          # Resizes all images to 48x48 pixels
    batch_size = 64,                 # Number of images per batch
    color_mode = "grayscale",        # Converts the images to grayscale
    class_mode = "categorical",      # Classifies the images into 7 categories
    subset = "training"              # Uses the training subset of the data
)

validation_generator = validation_datagen.flow_from_directory(
    directory = 'test',            # Directory containing the validation data
    target_size = (48, 48),          # Resizes all images to 48x48 pixels
    batch_size = 64,                 # Number of images per batch
    color_mode = "grayscale",        # Converts the images to grayscale
    class_mode = "categorical",      # Classifies the images into 7 categories
    subset = "validation"            # Uses the validation subset of the data
)
# Out:
# Found 22968 images belonging to 7 classes.
# Found 1432 images belonging to 7 classes.

# %%
# Define the model architecture
model = Sequential()

# Add a convolutional layer with 32 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(48,48,1)))
# Add a batch normalization layer
model.add(BatchNormalization())
# Add a second convolutional layer with 64 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
# Add a second batch normalization layer
model.add(BatchNormalization())
# Add a max pooling layer with 2x2 pool size
model.add(MaxPooling2D(pool_size=(2, 2)))
# Add a dropout layer with 0.25 dropout rate
model.add(Dropout(0.25))

# Add a third convolutional layer with 128 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Add a third batch normalization layer
model.add(BatchNormalization())
# Add a fourth convolutional layer with 128 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Add a fourth batch normalization layer
model.add(BatchNormalization())
# Add a max pooling layer with 2x2 pool size
model.add(MaxPooling2D(pool_size=(2, 2)))
# Add a dropout layer with 0.25 dropout rate
model.add(Dropout(0.25))

# Add a fifth convolutional layer with 256 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(256, kernel_size=(3, 3), activation='relu'))
# Add a fifth batch normalization layer
model.add(BatchNormalization())
# Add a sixth convolutional layer with 256 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(256, kernel_size=(3, 3), activation='relu'))
# Add a sixth batch normalization layer
model.add(BatchNormalization())
# Add a max pooling layer with 2x2 pool size
model.add(MaxPooling2D(pool_size=(2, 2)))
# Add a dropout layer with 0.25 dropout rate
model.add(Dropout(0.25))

# Flatten the output of the convolutional layers
model.add(Flatten())
# Add a dense layer with 256 neurons and relu activation function
model.add(Dense(256, activation='relu'))
# Add a seventh batch normalization layer
model.add(BatchNormalization())
# Add a dropout layer with 0.5 dropout rate
model.add(Dropout(0.5))
# Add a dense layer with 7 neurons (one for each class) and softmax activation function
model.add(Dense(7, activation='softmax'))

# Compile the model with categorical cross-entropy loss, adam optimizer, and accuracy metric
model.compile(loss="categorical_crossentropy", optimizer= tf.keras.optimizers.Adam(learning_rate=0.0001), metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

# Define the callback
checkpoint_callback = ModelCheckpoint(
    filepath='model_weights.h5',
    monitor='val_accuracy',
    save_best_only=True,
    save_weights_only=True,
    mode='max',
    verbose=1
)

# Train the model with the callback
history = model.fit(
    train_generator,
    steps_per_epoch=len(train_generator),
    epochs=50,
    validation_data=validation_generator,
    validation_steps=len(validation_generator),
    callbacks=[checkpoint_callback]
)
# Out:
# Epoch 1/50
# 359/359 [==============================] - ETA: 0s - loss: 2.8363 - accuracy: 0.1786
# Epoch 1: val_accuracy improved from -inf to 0.16620, saving model to model_weights.h5
# 359/359 [==============================] - 41s 75ms/step - loss: 2.8363 - accuracy: 0.1786 - val_loss: 2.2499 - val_accuracy: 0.1662
# Epoch 2/50
# 359/359 [==============================] - ETA: 0s - loss: 2.4542 - accuracy: 0.2115
# Epoch 2: val_accuracy improved from 0.16620 to 0.32891, saving model to model_weights.h5
# 359/359 [==============================] - 26s 73ms/step - loss: 2.4542 - accuracy: 0.2115 - val_loss: 1.7803 - val_accuracy: 0.3289
# Epoch 3/50
# 359/359 [==============================] - ETA: 0s - loss: 2.2416 - accuracy: 0.2504
# Epoch 3: val_accuracy improved from 0.32891 to 0.36173, saving model to model_weights.h5
# 359/359 [==============================] - 26s 73ms/step - loss: 2.2416 - accuracy: 0.2504 - val_loss: 1.6702 - val_accuracy: 0.3617
# Epoch 4/50
# 359/359 [==============================] - ETA: 0s - loss: 2.1036 - accuracy: 0.2788
# Epoch 4: val_accuracy improved from 0.36173 to 0.36732, saving model to model_weights.h5
# 359/359 [==============================] - 25s 70ms/step - loss: 2.1036 - accuracy: 0.2788 - val_loss: 1.6803 - val_accuracy: 0.3673
# Epoch 5/50
# 359/359 [==============================] - ETA: 0s - loss: 1.9872 - accuracy: 0.3054
# Epoch 5: val_accuracy improved from 0.36732 to 0.37570, saving model to model_weights.h5
# 359/359 [==============================] - 25s 70ms/step - loss: 1.9872 - accuracy: 0.3054 - val_loss: 1.6544 - val_accuracy: 0.3757
# Epoch 6/50
# 359/359 [==============================] - ETA: 0s - loss: 1.8988 - accuracy: 0.3284
# Epoch 6: val_accuracy improved from 0.37570 to 0.40154, saving model to model_weights.h5
# 359/359 [==============================] - 25s 69ms/step - loss: 1.8988 - accuracy: 0.3284 - val_loss: 1.5666 - val_accuracy: 0.4015
# Epoch 7/50
# 359/359 [==============================] - ETA: 0s - loss: 1.8266 - accuracy: 0.3477
# Epoch 7: val_accuracy did not improve from 0.40154
# 359/359 [==============================] - 26s 72ms/step - loss: 1.8266 - accuracy: 0.3477 - val_loss: 1.5926 - val_accuracy: 0.4001
# Epoch 8/50
# 359/359 [==============================] - ETA: 0s - loss: 1.7516 - accuracy: 0.3597
# Epoch 8: val_accuracy improved from 0.40154 to 0.46369, saving model to model_weights.h5
# 359/359 [==============================] - 26s 71ms/step - loss: 1.7516 - accuracy: 0.3597 - val_loss: 1.4661 - val_accuracy: 0.4637
# Epoch 9/50
# 359/359 [==============================] - ETA: 0s - loss: 1.6953 - accuracy: 0.3801
# Epoch 9: val_accuracy did not improve from 0.46369
# 359/359 [==============================] - 25s 70ms/step - loss: 1.6953 - accuracy: 0.3801 - val_loss: 1.4322 - val_accuracy: 0.4602
# Epoch 10/50
# 359/359 [==============================] - ETA: 0s - loss: 1.6291 - accuracy: 0.3987
# Epoch 10: val_accuracy improved from 0.46369 to 0.49721, saving model to model_weights.h5
# 359/359 [==============================] - 23s 65ms/step - loss: 1.6291 - accuracy: 0.3987 - val_loss: 1.3280 - val_accuracy: 0.4972
# Epoch 11/50
# 359/359 [==============================] - ETA: 0s - loss: 1.5854 - accuracy: 0.4128
# Epoch 11: val_accuracy did not improve from 0.49721
# 359/359 [==============================] - 25s 68ms/step - loss: 1.5854 - accuracy: 0.4128 - val_loss: 1.3356 - val_accuracy: 0.4972
# Epoch 12/50
# 359/359 [==============================] - ETA: 0s - loss: 1.5288 - accuracy: 0.4267
# Epoch 12: val_accuracy did not improve from 0.49721
# 359/359 [==============================] - 24s 68ms/step - loss: 1.5288 - accuracy: 0.4267 - val_loss: 1.3816 - val_accuracy: 0.4888
# Epoch 13/50
# 359/359 [==============================] - ETA: 0s - loss: 1.4871 - accuracy: 0.4429
# Epoch 13: val_accuracy improved from 0.49721 to 0.53492, saving model to model_weights.h5
# 359/359 [==============================] - 25s 69ms/step - loss: 1.4871 - accuracy: 0.4429 - val_loss: 1.2436 - val_accuracy: 0.5349
# Epoch 14/50
# 359/359 [==============================] - ETA: 0s - loss: 1.4428 - accuracy: 0.4589
# Epoch 14: val_accuracy improved from 0.53492 to 0.54190, saving model to model_weights.h5
# 359/359 [==============================] - 25s 69ms/step - loss: 1.4428 - accuracy: 0.4589 - val_loss: 1.2411 - val_accuracy: 0.5419
# Epoch 15/50
# 359/359 [==============================] - ETA: 0s - loss: 1.4031 - accuracy: 0.4721
# Epoch 15: val_accuracy did not improve from 0.54190
# 359/359 [==============================] - 25s 69ms/step - loss: 1.4031 - accuracy: 0.4721 - val_loss: 1.2314 - val_accuracy: 0.5356
# Epoch 16/50
# 359/359 [==============================] - ETA: 0s - loss: 1.3649 - accuracy: 0.4850
# Epoch 16: val_accuracy improved from 0.54190 to 0.54260, saving model to model_weights.h5
# 359/359 [==============================] - 25s 69ms/step - loss: 1.3649 - accuracy: 0.4850 - val_loss: 1.2184 - val_accuracy: 0.5426
# Epoch 17/50
# 359/359 [==============================] - ETA: 0s - loss: 1.3521 - accuracy: 0.4904
# Epoch 17: val_accuracy improved from 0.54260 to 0.56425, saving model to model_weights.h5
# 359/359 [==============================] - 25s 68ms/step - loss: 1.3521 - accuracy: 0.4904 - val_loss: 1.1769 - val_accuracy: 0.5642
# Epoch 18/50
# 359/359 [==============================] - ETA: 0s - loss: 1.3185 - accuracy: 0.4985
# Epoch 18: val_accuracy did not improve from 0.56425
# 359/359 [==============================] - 24s 68ms/step - loss: 1.3185 - accuracy: 0.4985 - val_loss: 1.1668 - val_accuracy: 0.5559
# Epoch 19/50
# 359/359 [==============================] - ETA: 0s - loss: 1.2893 - accuracy: 0.5132
# Epoch 19: val_accuracy improved from 0.56425 to 0.57193, saving model to model_weights.h5
# 359/359 [==============================] - 24s 66ms/step - loss: 1.2893 - accuracy: 0.5132 - val_loss: 1.1486 - val_accuracy: 0.5719
# Epoch 20/50
# 359/359 [==============================] - ETA: 0s - loss: 1.2758 - accuracy: 0.5205
# Epoch 20: val_accuracy improved from 0.57193 to 0.57682, saving model to model_weights.h5
# 359/359 [==============================] - 24s 67ms/step - loss: 1.2758 - accuracy: 0.5205 - val_loss: 1.1262 - val_accuracy: 0.5768
# Epoch 21/50
# 359/359 [==============================] - ETA: 0s - loss: 1.2497 - accuracy: 0.5283
# Epoch 21: val_accuracy improved from 0.57682 to 0.58031, saving model to model_weights.h5
# 359/359 [==============================] - 25s 69ms/step - loss: 1.2497 - accuracy: 0.5283 - val_loss: 1.1000 - val_accuracy: 0.5803
# Epoch 22/50
# 359/359 [==============================] - ETA: 0s - loss: 1.2345 - accuracy: 0.5357
# Epoch 22: val_accuracy improved from 0.58031 to 0.58450, saving model to model_weights.h5
# 359/359 [==============================] - 25s 69ms/step - loss: 1.2345 - accuracy: 0.5357 - val_loss: 1.1234 - val_accuracy: 0.5845
# Epoch 23/50
# 359/359 [==============================] - ETA: 0s - loss: 1.2192 - accuracy: 0.5436
# Epoch 23: val_accuracy improved from 0.58450 to 0.59707, saving model to model_weights.h5
# 359/359 [==============================] - 25s 69ms/step - loss: 1.2192 - accuracy: 0.5436 - val_loss: 1.0768 - val_accuracy: 0.5971
# Epoch 24/50
# 359/359 [==============================] - ETA: 0s - loss: 1.2013 - accuracy: 0.5475
# Epoch 24: val_accuracy improved from 0.59707 to 0.59916, saving model to model_weights.h5
# 359/359 [==============================] - 25s 69ms/step - loss: 1.2013 - accuracy: 0.5475 - val_loss: 1.0716 - val_accuracy: 0.5992
# Epoch 25/50
# 359/359 [==============================] - ETA: 0s - loss: 1.1972 - accuracy: 0.5514
# Epoch 25: val_accuracy did not improve from 0.59916
# 359/359 [==============================] - 25s 68ms/step - loss: 1.1972 - accuracy: 0.5514 - val_loss: 1.0604 - val_accuracy: 0.5971
# Epoch 26/50
# 359/359 [==============================] - ETA: 0s - loss: 1.1789 - accuracy: 0.5549
# Epoch 26: val_accuracy did not improve from 0.59916
# 359/359 [==============================] - 24s 65ms/step - loss: 1.1789 - accuracy: 0.5549 - val_loss: 1.0931 - val_accuracy: 0.5887
# Epoch 27/50
# 359/359 [==============================] - ETA: 0s - loss: 1.1561 - accuracy: 0.5633
# Epoch 27: val_accuracy improved from 0.59916 to 0.61313, saving model to model_weights.h5
# 359/359 [==============================] - 24s 68ms/step - loss: 1.1561 - accuracy: 0.5633 - val_loss: 1.0483 - val_accuracy: 0.6131
# Epoch 28/50
# 359/359 [==============================] - ETA: 0s - loss: 1.1522 - accuracy: 0.5659
# Epoch 28: val_accuracy did not improve from 0.61313
# 359/359 [==============================] - 25s 68ms/step - loss: 1.1522 - accuracy: 0.5659 - val_loss: 1.0833 - val_accuracy: 0.5922
# Epoch 29/50
# 359/359 [==============================] - ETA: 0s - loss: 1.1389 - accuracy: 0.5691
# Epoch 29: val_accuracy did not improve from 0.61313
# 359/359 [==============================] - 24s 67ms/step - loss: 1.1389 - accuracy: 0.5691 - val_loss: 1.0492 - val_accuracy: 0.6006
# Epoch 30/50
# 359/359 [==============================] - ETA: 0s - loss: 1.1309 - accuracy: 0.5739
# Epoch 30: val_accuracy improved from 0.61313 to 0.61592, saving model to model_weights.h5
# 359/359 [==============================] - 24s 66ms/step - loss: 1.1309 - accuracy: 0.5739 - val_loss: 1.0184 - val_accuracy: 0.6159
# Epoch 31/50
# 359/359 [==============================] - ETA: 0s - loss: 1.1183 - accuracy: 0.5809
# Epoch 31: val_accuracy improved from 0.61592 to 0.61732, saving model to model_weights.h5
# 359/359 [==============================] - 25s 69ms/step - loss: 1.1183 - accuracy: 0.5809 - val_loss: 1.0389 - val_accuracy: 0.6173
# Epoch 32/50
# 359/359 [==============================] - ETA: 0s - loss: 1.1083 - accuracy: 0.5831
# Epoch 32: val_accuracy improved from 0.61732 to 0.62081, saving model to model_weights.h5
# 359/359 [==============================] - 25s 69ms/step - loss: 1.1083 - accuracy: 0.5831 - val_loss: 1.0375 - val_accuracy: 0.6208
# Epoch 33/50
# 359/359 [==============================] - ETA: 0s - loss: 1.1039 - accuracy: 0.5880
# Epoch 33: val_accuracy improved from 0.62081 to 0.62919, saving model to model_weights.h5
# 359/359 [==============================] - 25s 69ms/step - loss: 1.1039 - accuracy: 0.5880 - val_loss: 1.0115 - val_accuracy: 0.6292
# Epoch 34/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0888 - accuracy: 0.5936
# Epoch 34: val_accuracy did not improve from 0.62919
# 359/359 [==============================] - 25s 69ms/step - loss: 1.0888 - accuracy: 0.5936 - val_loss: 1.0350 - val_accuracy: 0.6103
# Epoch 35/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0720 - accuracy: 0.6003
# Epoch 35: val_accuracy did not improve from 0.62919
# 359/359 [==============================] - 25s 68ms/step - loss: 1.0720 - accuracy: 0.6003 - val_loss: 1.0150 - val_accuracy: 0.6229
# Epoch 36/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0737 - accuracy: 0.5968
# Epoch 36: val_accuracy did not improve from 0.62919
# 359/359 [==============================] - 24s 67ms/step - loss: 1.0737 - accuracy: 0.5968 - val_loss: 1.0036 - val_accuracy: 0.6250
# Epoch 37/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0686 - accuracy: 0.6029
# Epoch 37: val_accuracy did not improve from 0.62919
# 359/359 [==============================] - 25s 69ms/step - loss: 1.0686 - accuracy: 0.6029 - val_loss: 0.9956 - val_accuracy: 0.6236
# Epoch 38/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0571 - accuracy: 0.6065
# Epoch 38: val_accuracy improved from 0.62919 to 0.62989, saving model to model_weights.h5
# 359/359 [==============================] - 25s 69ms/step - loss: 1.0571 - accuracy: 0.6065 - val_loss: 0.9856 - val_accuracy: 0.6299
# Epoch 39/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0441 - accuracy: 0.6068
# Epoch 39: val_accuracy did not improve from 0.62989
# 359/359 [==============================] - 25s 68ms/step - loss: 1.0441 - accuracy: 0.6068 - val_loss: 0.9982 - val_accuracy: 0.6229
# Epoch 40/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0482 - accuracy: 0.6078
# Epoch 40: val_accuracy did not improve from 0.62989
# 359/359 [==============================] - 25s 70ms/step - loss: 1.0482 - accuracy: 0.6078 - val_loss: 0.9984 - val_accuracy: 0.6201
# Epoch 41/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0319 - accuracy: 0.6131
# Epoch 41: val_accuracy improved from 0.62989 to 0.63478, saving model to model_weights.h5
# 359/359 [==============================] - 25s 69ms/step - loss: 1.0319 - accuracy: 0.6131 - val_loss: 0.9993 - val_accuracy: 0.6348
# Epoch 42/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0243 - accuracy: 0.6157
# Epoch 42: val_accuracy did not improve from 0.63478
# 359/359 [==============================] - 25s 68ms/step - loss: 1.0243 - accuracy: 0.6157 - val_loss: 0.9725 - val_accuracy: 0.6292
# Epoch 43/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0250 - accuracy: 0.6151
# Epoch 43: val_accuracy improved from 0.63478 to 0.63966, saving model to model_weights.h5
# 359/359 [==============================] - 24s 68ms/step - loss: 1.0250 - accuracy: 0.6151 - val_loss: 0.9558 - val_accuracy: 0.6397
# Epoch 44/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0167 - accuracy: 0.6193
# Epoch 44: val_accuracy did not improve from 0.63966
# 359/359 [==============================] - 25s 69ms/step - loss: 1.0167 - accuracy: 0.6193 - val_loss: 0.9632 - val_accuracy: 0.6362
# Epoch 45/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0031 - accuracy: 0.6264
# Epoch 45: val_accuracy improved from 0.63966 to 0.64595, saving model to model_weights.h5
# 359/359 [==============================] - 25s 68ms/step - loss: 1.0031 - accuracy: 0.6264 - val_loss: 0.9571 - val_accuracy: 0.6459
# Epoch 46/50
# 359/359 [==============================] - ETA: 0s - loss: 0.9975 - accuracy: 0.6302
# Epoch 46: val_accuracy did not improve from 0.64595
# 359/359 [==============================] - 25s 70ms/step - loss: 0.9975 - accuracy: 0.6302 - val_loss: 0.9392 - val_accuracy: 0.6397
# Epoch 47/50
# 359/359 [==============================] - ETA: 0s - loss: 0.9886 - accuracy: 0.6296
# Epoch 47: val_accuracy did not improve from 0.64595
# 359/359 [==============================] - 24s 67ms/step - loss: 0.9886 - accuracy: 0.6296 - val_loss: 0.9532 - val_accuracy: 0.6459
# Epoch 48/50
# 359/359 [==============================] - ETA: 0s - loss: 0.9798 - accuracy: 0.6321
# Epoch 48: val_accuracy did not improve from 0.64595
# 359/359 [==============================] - 25s 69ms/step - loss: 0.9798 - accuracy: 0.6321 - val_loss: 0.9396 - val_accuracy: 0.6446
# Epoch 49/50
# 359/359 [==============================] - ETA: 0s - loss: 0.9786 - accuracy: 0.6331
# Epoch 49: val_accuracy improved from 0.64595 to 0.66131, saving model to model_weights.h5
# 359/359 [==============================] - 24s 68ms/step - loss: 0.9786 - accuracy: 0.6331 - val_loss: 0.9246 - val_accuracy: 0.6613
# Epoch 50/50
# 359/359 [==============================] - ETA: 0s - loss: 0.9772 - accuracy: 0.6336
# Epoch 50: val_accuracy did not improve from 0.66131
# 359/359 [==============================] - 25s 69ms/step - loss: 0.9772 - accuracy: 0.6336 - val_loss: 0.9410 - val_accuracy: 0.6536

# %%
# Plot the train and validation loss
train_loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(train_loss) + 1)
plt.plot(epochs, train_loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Plot the train and validation accuracy
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.plot(epochs, train_acc, 'bo', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Get the true labels and predicted labels for the validation set
validation_labels = validation_generator.classes
validation_pred_probs = model.predict(validation_generator)
validation_pred_labels = np.argmax(validation_pred_probs, axis=1)

# Compute the confusion matrix
confusion_mtx = confusion_matrix(validation_labels, validation_pred_labels)
class_names = list(train_generator.class_indices.keys())
sns.set()
sns.heatmap(confusion_mtx, annot=True, fmt='d', cmap='YlGnBu',
            xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 23/23 [==============================] - 1s 24ms/step
